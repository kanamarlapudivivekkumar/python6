# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# to access in csv file
df=pd.read_csv(r"path of file")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # to access in csv file
# ----> 2 df=pd.read_csv(r"path of file")
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='payment',y='total',data=df,color='red',estimator='std')
plt.show()
plt.tight_layout()

# %%
sns.barplot(x='total',y='payment',data=df,color='red',estimator='std')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df['fare'],color='blue')
plt.show()

# %%
sns.histplot(x=df['fare'],palette=['blue','red'],hue=df['payment'])
plt.show()

# %%
sns.histplot(x=df['fare'],palette=['g','y'],hue=df['payment'])
plt.show()

# %%
# histogram plot
sns.distplot(x=df['fare'],hist=True,kde=False)
                      
plt.show()

# %%
# distribution plot
sns.distplot(x=df['fare'],hist=False,kde=True)
plt.show()

# %%
sns.distplot(x=df['fare'],hist=True,kde=True)
plt.show()

# %%
sns.boxplot(x=df['fare'],color='pink')
plt.show()

# %%
iris_dataset=sns.load_dataset('iris')
iris_dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=iris_dataset['petal_length'],color='violet')
plt.show()

# %%
lower_bound= q1-1.5iqr

upper_bound =q3+ 1.5iqr

iqr=q3-q1
# Out:
#   Cell In[15], line 1
#     lower_bound= q1-1.5iqr
#                       ^
# SyntaxError: invalid decimal literal

# %%
sns.boxplot(x=iris_dataset['sepal_width'],palette=['violet','red','lightgreen'],y=iris_dataset['species'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset('iris')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],palette=['red','blue','green'])
plt.show()

# %%
sns.stripplot(x=iris_data['species'],y=iris_data['sepal_width'],palette=['r','g','y'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.lineplot(x=df['tip'],y=df['fare'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['orange','yellow'])
plt.show()

# %%
df[(df['payment']=='cash') & (df['tip']>0)]
# Out:
# Empty DataFrame
# Columns: [pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, dropoff_borough]
# Index: []

# %%
sns.lineplot(x=df['tip'],y=df['fare'],hue=df['payment'],palette=['green','orange'])
plt.show()

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','yellow'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns
