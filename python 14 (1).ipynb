# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
lb
# Out:
# LabelEncoder()

# %%
df['smoker']=lb.fit_transform(df['smoker'])
df['sex']=lb.fit_transform(df['sex'])
df['time']=lb.fit_transform(df['time'])
df['day']=lb.fit_transform(df['day'])

# %%
df['smoker']
df['sex']
df['time']
df['day']
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 239    1
# 240    1
# 241    1
# 242    1
# 243    3
# Name: day, Length: 244, dtype: int32

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex             int32
# smoker          int32
# day             int32
# time            int32
# size            int64
# dtype: object

# %%
df.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
df.corr() # corr means the relation between two variables
# Out:
#             total_bill       tip       sex    smoker       day      time  \
# total_bill    1.000000  0.675734  0.144877  0.085721 -0.043550 -0.183118
# tip           0.675734  1.000000  0.088862  0.005929 -0.011548 -0.121629
# sex           0.144877  0.088862  1.000000  0.002816 -0.078292 -0.205231
# smoker        0.085721  0.005929  0.002816  1.000000 -0.282721 -0.054921
# day          -0.043550 -0.011548 -0.078292 -0.282721  1.000000  0.638019
# time         -0.183118 -0.121629 -0.205231 -0.054921  0.638019  1.000000
# size          0.598315  0.489299  0.086195 -0.133178  0.069510 -0.103411
#
#                 size
# total_bill  0.598315
# tip         0.489299
# sex         0.086195
# smoker     -0.133178
# day         0.069510
# time       -0.103411
# size        1.000000

# %%
df.head(4)
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2

# %%
df.tail(3)
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr()),cmap='Purples')
plt.show()

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kvive\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kvive\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kvive\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr())>0.5,cmap='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 sns.heatmap(np.abs(df.corr())>0.5,cmap='red')
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:217, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     215         self.cmap = cm.icefire
#     216 elif isinstance(cmap, str):
# --> 217     self.cmap = get_colormap(cmap)
#     218 elif isinstance(cmap, list):
#     219     self.cmap = mpl.colors.ListedColormap(cmap)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_compat.py:133, in get_colormap(name)
#     131 """Handle changes to matplotlib colormap interface in 3.6."""
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#     135     return mpl.cm.get_cmap(name)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cm.py:82, in ColormapRegistry.__getitem__(self, item)
#      80     return self._cmaps[item].copy()
#      81 except KeyError:
# ---> 82     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'red' is not a known colormap name"

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr()),cmap='Purple',annot=True)
plt.show()

# %%
sns.heatmap(np.abs(df.corr())>0.5,cmap="Green")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.heatmap(np.abs(df.corr())>0.5,cmap="Green")
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:217, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     215         self.cmap = cm.icefire
#     216 elif isinstance(cmap, str):
# --> 217     self.cmap = get_colormap(cmap)
#     218 elif isinstance(cmap, list):
#     219     self.cmap = mpl.colors.ListedColormap(cmap)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_compat.py:133, in get_colormap(name)
#     131 """Handle changes to matplotlib colormap interface in 3.6."""
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#     135     return mpl.cm.get_cmap(name)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cm.py:82, in ColormapRegistry.__getitem__(self, item)
#      80     return self._cmaps[item].copy()
#      81 except KeyError:
# ---> 82     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'Green' is not a known colormap name"

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    2     0     2
# 1         10.34  1.66    1       0    2     0     3
# 2         21.01  3.50    1       0    2     0     3
# 3         23.68  3.31    1       0    2     0     2
# 4         24.59  3.61    0       0    2     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip         sex      smoker         day        time  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.643443    0.381148    1.741803    0.278689
# std      8.902412    1.383638    0.479967    0.486667    0.926815    0.449276
# min      3.070000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     13.347500    2.000000    0.000000    0.000000    1.000000    0.000000
# 50%     17.795000    2.900000    1.000000    0.000000    2.000000    0.000000
# 75%     24.127500    3.562500    1.000000    1.000000    3.000000    1.000000
# max     50.810000   10.000000    1.000000    1.000000    3.000000    1.000000
#
#              size
# count  244.000000
# mean     2.569672
# std      0.951100
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      6.000000

# %%
scaling techniques
1) standardization ----> mean 0 and std of 1

2) normalization ----> range of 0 to 1 inclusive

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
sc_array=sc.fit_transform(df)

# %%
sc_array.shape
# Out:
# (244, 7)

# %%
SC_df=pd.DataFrame(sc_array,columns=df.columns)
SC_df.head(3)
# Out:
#    total_bill       tip       sex    smoker       day      time      size
# 0   -0.314711 -1.439947 -1.343353 -0.784789  0.279158 -0.621582 -0.600193
# 1   -1.063235 -0.969205  0.744406 -0.784789  0.279158 -0.621582  0.453383
# 2    0.137780  0.363356  0.744406 -0.784789  0.279158 -0.621582  0.453383

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#        total_bill         tip         sex      smoker         day        time  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.643443    0.381148    1.741803    0.278689
# std      8.902412    1.383638    0.479967    0.486667    0.926815    0.449276
# min      3.070000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     13.347500    2.000000    0.000000    0.000000    1.000000    0.000000
# 50%     17.795000    2.900000    1.000000    0.000000    2.000000    0.000000
# 75%     24.127500    3.562500    1.000000    1.000000    3.000000    1.000000
# max     50.810000   10.000000    1.000000    1.000000    3.000000    1.000000
#
#              size
# count  244.000000
# mean     2.569672
# std      0.951100
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      6.000000

# %%
from sklearn.preprocessing import MinMaxScaler
mx_scaler=MinMaxScaler()

# %%
mx_scaler
# Out:
# MinMaxScaler()

# %%
mx_array=mx_scaler.fit_transform(df)

# %%
type(mx_array)
# Out:
# numpy.ndarray

# %%
mx_array.shape
# Out:
# (244, 7)

# %%
mx_array
# Out:
# array([[0.29157939, 0.00111111, 0.        , ..., 0.66666667, 0.        ,
#         0.2       ],
#        [0.1522832 , 0.07333333, 1.        , ..., 0.66666667, 0.        ,
#         0.4       ],
#        [0.3757855 , 0.27777778, 1.        , ..., 0.66666667, 0.        ,
#         0.4       ],
#        ...,
#        [0.41055718, 0.11111111, 1.        , ..., 0.33333333, 0.        ,
#         0.2       ],
#        [0.30896523, 0.08333333, 1.        , ..., 0.33333333, 0.        ,
#         0.2       ],
#        [0.32907415, 0.22222222, 0.        , ..., 1.        , 0.        ,
#         0.2       ]])

# %%
mx_df=pd.DataFrame(mx_array,columns=df.columns)
mx_df
# Out:
#      total_bill       tip  sex  smoker       day  time  size
# 0      0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1      0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2      0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3      0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4      0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6
# ..          ...       ...  ...     ...       ...   ...   ...
# 239    0.543779  0.546667  1.0     0.0  0.333333   0.0   0.4
# 240    0.505027  0.111111  0.0     1.0  0.333333   0.0   0.2
# 241    0.410557  0.111111  1.0     1.0  0.333333   0.0   0.2
# 242    0.308965  0.083333  1.0     0.0  0.333333   0.0   0.2
# 243    0.329074  0.222222  0.0     0.0  1.000000   0.0   0.2
#
# [244 rows x 7 columns]

# %%
mx_df.describe()
# Out:
#        total_bill         tip         sex      smoker         day        time  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean     0.350145    0.222031    0.643443    0.381148    0.580601    0.278689
# std      0.186477    0.153738    0.479967    0.486667    0.308938    0.449276
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.215281    0.111111    0.000000    0.000000    0.333333    0.000000
# 50%      0.308442    0.211111    1.000000    0.000000    0.666667    0.000000
# 75%      0.441087    0.284722    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              size
# count  244.000000
# mean     0.313934
# std      0.190220
# min      0.000000
# 25%      0.200000
# 50%      0.200000
# 75%      0.400000
# max      1.000000

# %%
import statsmodels.api as sm
sm.qqplot(df['total_bill'],line='45')
plt.show()

# %%
sns.regplot(x='total_bill',y='tip',data=df,ci=None,line_kws={'color':'red'},scatter_kws={'color':'green'})
plt.show()
